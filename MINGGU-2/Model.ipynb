# %%
import pandas as pd

data = pd.read_csv('clean_dataset.csv' , sep=';')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 902 entries, 0 to 901
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    902 non-null    int64
#  1   Tweet         902 non-null    object
#  2   Sentimen      902 non-null    float64
#  3   step01        902 non-null    object
#  4   tokens        902 non-null    object
#  5   final_tokens  902 non-null    object
#  6   step02        902 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 49.5+ KB

# %%
data.head(25)
# Out:
#     Unnamed: 0                                              Tweet  Sentimen  \
# 0            0  Cegah mata rantai Covid-19,mari kita dirumah s...       1.0
# 1            1  aku mohon yaAllah semoga wabah covid-19 menghi...       1.0
# 2            2  Pemprov Papua Naikkan Status Jadi Tanggap Daru...       1.0
# 3            3            Covid belum nyampe prigen mbak hmm hoax       0.0
# 4            4  Nyuruh orang pintar, lu aja Togog. Itu kerumun...      -1.0
# 5            5  Pikir2 balik byk mnde plk nk setelkn lepas covid.       0.0
# 6            6  Selamat pagi, hari jum'at. Jum'at keempat di k...       1.0
# 7            7  Hikmah di balik musibah covid-19, smg para pej...       1.0
# 8            8  Cegah covid-19 beserta jajaran Polsek Kuranji ...       1.0
# 9            9  Ya Allah kami memohon pada mu perkenankanlah d...       1.0
# 10          10  Sah.. Cegah Covid-19 Meluas, Pemerintah Revisi...       1.0
# ...

# %%
data[['Tweet']]
# Out:
#                                                  Tweet
# 0    Cegah mata rantai Covid-19,mari kita dirumah s...
# 1    aku mohon yaAllah semoga wabah covid-19 menghi...
# 2    Pemprov Papua Naikkan Status Jadi Tanggap Daru...
# 3              Covid belum nyampe prigen mbak hmm hoax
# 4    Nyuruh orang pintar, lu aja Togog. Itu kerumun...
# ..                                                 ...
# 897  Seluruh negara di dunia mengalami masa sulit k...
# 898  Setelah covid dan skripsi disaster selesai, ma...
# 899  Malam ini!! Projek "BENDA BOLEH BINCANG" 9 mal...
# 900                Pontang - panting di koyak covid 19
# 901  Masalahnya sekarang isu jangkitan covid. Alaaa...
#
# [902 rows x 1 columns]

# %%
kalimat = data.loc[4, 'Tweet']
lower_case = kalimat.lower()
print(lower_case)
# Out:
# nyuruh orang pintar, lu aja togog. itu kerumunan orang bisa nularin covid 19 lol. mikir !!!!
